# %% [markdown]
# # Comprensión de datos

# %% [markdown]
# ## **Recopilación de los datos**

# %% [markdown]
# Librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lectura de datos

# %%
datos = pd.read_excel("SALESDATA.xlsx")

# Mostrar los primeros registros
print(datos.head())
# Out:
#     Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31           398.73   2019-12-31          329568
# 1  10016609 2019-12-31           268.67   2019-12-31          329569
# 2  10016609 2019-12-31           398.73   2019-12-31          329569
# 3  10016609 2019-12-31           466.45   2019-12-31          329569
# 4  10016609 2019-12-31           515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number  List Price  \
# 0        P01       15640         Super Vegetable Oil         1000      163.47
# 1        P01       31681  Golden Fajita French Fries         7000      275.37
# 2        P01       15640         Super Vegetable Oil         4000      163.47
# 3        P01       13447            High Top Oranges         3000      119.52
# 4        P01       36942       Tell Tale New Potatos         9000      264.18
#
#    Order Number Promised Delivery Date  Sales Amount  \
# 0        122380             2019-12-31        418.62
# 1        123966             2019-12-31        282.07
# 2        123966             2019-12-31        418.62
# 3        123966             2019-12-31        489.71
# 4        123966             2019-12-31        541.21
#
#    Sales Amount Based on List Price  Sales Cost Amount  Sales Margin Amount  \
# 0                            817.35             102.99               315.63
# 1                            550.74             117.45               164.62
# 2                            817.35             102.99               315.63
# 3                            956.16             213.29               276.42
# 4                           1056.72             290.56               250.65
#
#    Sales Price  Sales Quantity  Sales Rep U/M
# 0     83.72400               5        176  EA
# 1    141.03500               2        176  EA
# 2     83.72400               5        176  EA
# 3     61.21375               8        176  EA
# 4    135.30250               4        176  EA

# %%
datos.head()
# Out:
#     Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31           398.73   2019-12-31          329568
# 1  10016609 2019-12-31           268.67   2019-12-31          329569
# 2  10016609 2019-12-31           398.73   2019-12-31          329569
# 3  10016609 2019-12-31           466.45   2019-12-31          329569
# 4  10016609 2019-12-31           515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number  List Price  \
# 0        P01       15640         Super Vegetable Oil         1000      163.47
# 1        P01       31681  Golden Fajita French Fries         7000      275.37
# 2        P01       15640         Super Vegetable Oil         4000      163.47
# 3        P01       13447            High Top Oranges         3000      119.52
# 4        P01       36942       Tell Tale New Potatos         9000      264.18
#
#    Order Number Promised Delivery Date  Sales Amount  \
# 0        122380             2019-12-31        418.62
# 1        123966             2019-12-31        282.07
# 2        123966             2019-12-31        418.62
# 3        123966             2019-12-31        489.71
# 4        123966             2019-12-31        541.21
#
#    Sales Amount Based on List Price  Sales Cost Amount  Sales Margin Amount  \
# 0                            817.35             102.99               315.63
# 1                            550.74             117.45               164.62
# 2                            817.35             102.99               315.63
# 3                            956.16             213.29               276.42
# 4                           1056.72             290.56               250.65
#
#    Sales Price  Sales Quantity  Sales Rep U/M
# 0     83.72400               5        176  EA
# 1    141.03500               2        176  EA
# 2     83.72400               5        176  EA
# 3     61.21375               8        176  EA
# 4    135.30250               4        176  EA

# %% [markdown]
# ## **Descripción de los datos**

# %%
# ¿Qué dimensiones tiene la base de datos (en números de filas y columnas)?
datos.shape
# Out:
# (65280, 20)

# %%
# Nombres de las columnas
datos.columns
# Out:
# Index(['Custkey', 'DateKey', 'Discount Amount', 'Invoice Date',
#        'Invoice Number', 'Item Class', 'Item Number', 'Item', 'Line Number',
#        'List Price', 'Order Number', 'Promised Delivery Date', 'Sales Amount',
#        'Sales Amount Based on List Price', 'Sales Cost Amount',
#        'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Rep',
#        'U/M'],
#       dtype='object')

# %%
# Tipos de datos de cada columna
datos.dtypes
# Out:
# Custkey                                      int64
# DateKey                             datetime64[ns]
# Discount Amount                            float64
# Invoice Date                        datetime64[ns]
# Invoice Number                               int64
# Item Class                                  object
# Item Number                                 object
# Item                                        object
# Line Number                                  int64
# List Price                                 float64
# Order Number                                 int64
# Promised Delivery Date              datetime64[ns]
# Sales Amount                               float64
# Sales Amount Based on List Price           float64
# Sales Cost Amount                          float64
# Sales Margin Amount                        float64
# Sales Price                                float64
# Sales Quantity                               int64
# Sales Rep                                    int64
# U/M                                         object
# dtype: object

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65280 entries, 0 to 65279
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           65280 non-null  int64
#  1   DateKey                           65280 non-null  datetime64[ns]
#  2   Discount Amount                   65278 non-null  float64
#  3   Invoice Date                      65280 non-null  datetime64[ns]
#  4   Invoice Number                    65280 non-null  int64
#  5   Item Class                        56995 non-null  object
#  6   Item Number                       65240 non-null  object
#  7   Item                              65280 non-null  object
#  8   Line Number                       65280 non-null  int64
#  9   List Price                        65280 non-null  float64
#  10  Order Number                      65280 non-null  int64
#  11  Promised Delivery Date            65280 non-null  datetime64[ns]
#  12  Sales Amount                      65280 non-null  float64
#  13  Sales Amount Based on List Price  65280 non-null  float64
#  14  Sales Cost Amount                 65280 non-null  float64
#  15  Sales Margin Amount               65280 non-null  float64
#  16  Sales Price                       65279 non-null  float64
#  17  Sales Quantity                    65280 non-null  int64
#  18  Sales Rep                         65280 non-null  int64
#  19  U/M                               65280 non-null  object
# dtypes: datetime64[ns](3), float64(7), int64(6), object(4)
# memory usage: 10.0+ MB

# %%
datos.describe(include='number')
# Out:
#             Custkey  Discount Amount  Invoice Number    Line Number  \
# count  6.528000e+04     65278.000000    65280.000000   65280.000000
# mean   1.001770e+07      1855.628805   216227.222089   23714.515043
# std    7.175933e+03      9037.273883    94991.559484   32664.303299
# min    1.000045e+07   -255820.800000   100080.000000    1000.000000
# 25%    1.001272e+07       246.067500   117931.000000    3000.000000
# 50%    1.001966e+07       441.760000   222870.500000   12000.000000
# 75%    1.002351e+07       999.760000   314319.250000   32000.000000
# max    1.002758e+07    343532.660000   332842.000000  344000.000000
#
#          List Price   Order Number   Sales Amount  \
# count  65280.000000   65280.000000   65280.000000
# mean     514.705779  180582.468673    2852.118522
# std      449.190065   67594.820895   15164.567492
# min        0.000000  100838.000000     200.010000
# 25%      181.560000  115319.750000     308.410000
# 50%      325.190000  203702.000000     553.970000
# 75%      803.860000  218576.000000    1280.070000
# max     2760.700000  321532.000000  555376.000000
#
#        Sales Amount Based on List Price  Sales Cost Amount  \
# count                      65280.000000       65280.000000
# mean                        4707.607727        1661.030116
# std                        20696.746564        9556.627220
# min                            0.000000           0.000000
# 25%                          561.040000         167.790000
# 50%                          998.160000         304.530000
# 75%                         2316.630000         687.400000
# max                       632610.160000      366576.000000
#
#        Sales Margin Amount   Sales Price  Sales Quantity     Sales Rep
# count         65280.000000  65279.000000    65280.000000  65280.000000
# mean           1191.088407    283.619763       45.085631    137.421998
# std            5860.874897    252.879249      429.668309     26.643601
# min           -3932.930000  -5000.000000       -1.000000    103.000000
# 25%             129.947500    100.070000        2.000000    113.000000
# 50%             246.490000    183.757500        3.000000    134.000000
# 75%             579.600000    448.220000        8.000000    160.000000
# max          188800.000000   6035.000000    16000.000000    185.000000

# %%
datos[datos['Discount Amount']==343532.660000]
# Out:
#         Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 11716  10025571 2019-08-17        343532.66   2019-08-17          309496
# 25805  10025571 2019-02-16        343532.66   2019-02-16          321884
#
#       Item Class Item Number                           Item  Line Number  \
# 11716        NaN       62653  Tell Tale Red Delcious Apples         4000
# 25805        NaN       62653  Tell Tale Red Delcious Apples         4000
#
#        List Price  Order Number Promised Delivery Date  Sales Amount  \
# 11716     279.916        101641             2019-08-17      289077.5
# 25805     279.916        115968             2019-02-16      289077.5
#
#        Sales Amount Based on List Price  Sales Cost Amount  \
# 11716                         632610.16          153635.03
# 25805                         632610.16          153635.03
#
#        Sales Margin Amount  Sales Price  Sales Quantity  Sales Rep U/M
# 11716            135442.47   127.910398            2260        134  EA
# 25805            135442.47   127.910398            2260        134  EA

# %%
print("El tamaño del archivo de datos es: ", datos.shape, "\n")
print("El número de entradas en 65280 filas para cada característica es:\n")
datos.count()
# Out:
# El tamaño del archivo de datos es:  (65280, 20)
#
# El número de entradas en 65280 filas para cada característica es:
# Custkey                             65280
# DateKey                             65280
# Discount Amount                     65278
# Invoice Date                        65280
# Invoice Number                      65280
# Item Class                          56995
# Item Number                         65240
# Item                                65280
# Line Number                         65280
# List Price                          65280
# Order Number                        65280
# Promised Delivery Date              65280
# Sales Amount                        65280
# Sales Amount Based on List Price    65280
# Sales Cost Amount                   65280
# Sales Margin Amount                 65280
# Sales Price                         65279
# Sales Quantity                      65280
# Sales Rep                           65280
# U/M                                 65280
# dtype: int64

# %%
datos.groupby('Custkey')['Sales Price'].describe()
# Out:
#           count        mean         std         min         25%         50%  \
# Custkey
# 10000453  329.0  326.060493  236.574141   48.253600  123.645000  258.160000
# 10000455   19.0  122.129412   29.758362   60.600000  115.404000  141.000000
# 10000456  104.0  250.153016  230.348576    6.957667   84.353333  140.026667
# 10000457   19.0  312.544544  312.053355   25.972500   49.600000  110.265000
# 10000458   10.0  174.538400  168.064093   17.218667   28.518500  132.048000
# ...         ...         ...         ...         ...         ...         ...
# 10027381  108.0  278.483106  223.002071   20.679000  105.402500  233.850000
# 10027560   42.0  493.833786  330.110124  102.690000  131.995000  579.865000
# 10027572   52.0  441.795483  235.430792   71.595000  269.892500  463.920000
# 10027575    5.0  532.836000  271.840768  292.990000  301.230000  429.030000
# 10027583   25.0  512.328533  278.990297   69.496000  209.597000  630.606667
#
#                  75%          max
# Custkey
# 10000453  513.030000   864.125000
# 10000455  141.000000   144.546667
# 10000456  461.329500   801.902000
# 10000457  547.179500   900.130000
# 10000458  341.803500   407.328000
# ...              ...          ...
# 10027381  371.556250  1113.140000
# 10027560  793.020000   976.700000
# 10027572  641.665417   946.450000
# 10027575  756.490000   884.440000
# 10027583  674.850000   946.450000
#
# [615 rows x 8 columns]

# %% [markdown]
# ## **Exploración de los datos**

# %%
datos.sample(5)
# Out:
#         Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 41850  10025919 2017-10-15        1028.2602   2017-10-15          115873
# 12023  10024022 2019-08-12         730.5000   2019-08-12          309051
# 15076  10019194 2019-07-05         618.8600   2019-07-05          305776
# 39119  10012226 2017-11-17        8442.4400   2017-11-17          118771
# 45975  10022678 2017-08-29         606.8400   2017-08-29          111809
#
#       Item Class Item Number                          Item  Line Number  \
# 41850        P01       28500                  Ebony Squash        27000
# 12023        P01       37606      Colony Blueberry Muffins        23000
# 15076        P01       38804         Ebony Elephant Garlic       124000
# 39119        P01       32963     High Top Macintosh Apples         1001
# 45975        P01       17801  Better Fancy Canned Sardines         3000
#
#        List Price  Order Number Promised Delivery Date  Sales Amount  \
# 41850   1058.6801        212875             2017-10-15       1089.10
# 12023    408.5200        107510             2019-08-11        903.58
# 15076    247.0700        105051             2019-07-03        616.49
# 39119    137.3200        214872             2017-11-17      11468.96
# 45975   1431.2300        209671             2017-08-29        824.39
#
#        Sales Amount Based on List Price  Sales Cost Amount  \
# 41850                         2117.3602             607.08
# 12023                         1634.0800             460.56
# 15076                         1235.3500             426.45
# 39119                        19911.4000            7675.39
# 45975                         1431.2300             449.69
#
#        Sales Margin Amount  Sales Price  Sales Quantity  Sales Rep U/M
# 41850               482.02   544.550000               2        108  EA
# 12023               443.02   225.895000               4        163  SE
# 15076               190.04   123.298000               5        108  EA
# 39119              3793.57    79.096276             145        184  EA
# 45975               374.70   824.390000               1        166  EA

# %%
print("El número de artículos en cada categoría es:\n")
pd.value_counts(datos['Item'])
# Out:
# El número de artículos en cada categoría es:
# Item
# Better Fancy Canned Sardines    1648
# Ebony Prepared Salad            1471
# Moms Sliced Turkey              1192
# Imagine Popsicles               1191
# Discover Manicotti              1126
#                                 ...
# BBB Best Corn Oil                  1
# Choice Bubble Gum                  1
# Atomic White Chocolate Bar         1
# Tell Tale Potatos                  1
# Discover Rice Medly                1
# Name: count, Length: 657, dtype: int64

# %% [markdown]
# `La mayor parte de los datos está constituida por esas 5 predominantes. Visualicemos esto mediante un diagrama de distribución de los top 10.`

# %%
# Calcular las frecuencias de cada categoría
frecuencias = datos['Item'].value_counts()
# Seleccionar las 10 más comunes
top_10 = frecuencias.head(10)
# Filtrar el DataFrame original para incluir solo las 10 categorías más comunes
datos_top_10 = datos[datos['Item'].isin(top_10.index)]

# Crear el gráfico utilizando el DataFrame filtrado
ax = sns.displot(data=datos_top_10, y='Item', aspect=3)
ax.set_axis_labels('Product Count', 'Prod Category')

# %% [markdown]
# `Aquí observamos mejor que la categoría predominante es la de Better Fancy Canned Sardines, que va cerca con la cantidad de productos que tiene Ebony Prepared Salad.`

# %%
# Gráfico de dispersión de 'Sales Quantity' vs 'Sales Amount'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales Quantity', y='Sales Amount', data=datos)
plt.title('Sales Quantity vs Sales Amount')
plt.xlabel('Sales Quantity')
plt.ylabel('Sales Amount')
plt.show()

# %% [markdown]
# `Se puede observar una tendencia general ascendente en los puntos, lo que sugiere una correlación positiva entre la cantidad vendida y el monto de ventas. Es decir, a medida que aumenta la cantidad de ventas, también tiende a aumentar el monto de ventas.Sin embargo, también se puede notar una considerable dispersión de los puntos, lo que indica que la relación no es perfectamente lineal. Hay casos en los que una cantidad de ventas similar puede tener montos de ventas bastante diferentes, y viceversa. `

# %%
frecuencia_item_class = datos['Item Class'].value_counts()
print(frecuencia_item_class)
# Out:
# Item Class
# P01    56965
# PO1       16
# P02        1
# P12        1
# P13        1
# P06        1
# P15        1
# P11        1
# P08        1
# P07        1
# P10        1
# P09        1
# P14        1
# P03        1
# P05        1
# P04        1
# Name: count, dtype: int64

# %%
# Crear un gráfico de barras
frecuencia_item_class.plot(kind='bar', figsize=(10, 6))


# Añadir títulos y etiquetas
plt.title('Número de artículos en cada clase de ítem')
plt.xlabel('Clase de ítem')
plt.ylabel('Número de artículos')


# Mostrar el gráfico
plt.show()

# %%
# Gráfico de dispersión entre precios de venta y precios de lista:
sns.scatterplot(x='List Price', y='Sales Price', data=datos)
# Out:
# <Axes: xlabel='List Price', ylabel='Sales Price'>

# %% [markdown]
# `La mayoría de los puntos se concentran a lo largo de una línea diagonal ascendente, lo que sugiere una correlación positiva entre el "List Price" y el "Sales Price". Es decir, a medida que el precio de lista aumenta, también lo hace el precio de venta. Sin embargo, hay una dispersión significativa de puntos por encima y por debajo de la línea diagonal, lo que indica que, aunque hay una relación general entre el precio de lista y el precio de venta, existen variaciones individuales.`

# %%
# Gráfico de barras para ventas por representante de ventas:
datos.groupby('Sales Rep')['Order Number'].sum().plot.bar()
# Out:
# <Axes: xlabel='Sales Rep'>

# %%
# Gráfico de barras para ventas por representante de ventas (TOP 5):

# Contar la cantidad de órdenes distintas por representante
ventas_por_rep = datos.groupby('Sales Rep')['Order Number'].nunique()
# Ordenar de manera descendente las ventas por representante
ventas_por_rep = ventas_por_rep.sort_values(ascending=False)

# Obtener los top 5 representantes con mayores ventas
top_5_reps = ventas_por_rep.head(5)

# Crear el gráfico de barras con valores reales en el eje y
fig, ax = plt.subplots(figsize=(10, 6))
top_5_reps.plot.bar(ax=ax, rot=0)
ax.set_xlabel('Cantidad de Órdenes', fontsize=12)
ax.set_ylabel('Ventas Totales', fontsize=12)
ax.set_title('Top 5 Representantes de Ventas por Cantidad de Órdenes', fontsize=14)
plt.show()

# %% [markdown]
# `Se puede observar que los top 5 de los representantes de ventas por cantidad de órdenes está liderado por los vendedores 108 y 180.`

# %%
# Gráfico de barras para Top 5 Representantes de Ventas con menor cantidad de
# órdenes de venta:

# Contar la cantidad de órdenes distintas por representante
ventas_por_rep = datos.groupby('Sales Rep')['Order Number'].nunique()
# Ordenar de manera descendente las ventas por representante
ventas_por_rep = ventas_por_rep.sort_values(ascending=True)

# Obtener los top 5 representantes con menores ventas
top_5_reps = ventas_por_rep.head(5)

# Crear el gráfico de barras con valores reales en el eje y
fig, ax = plt.subplots(figsize=(10, 6))
top_5_reps.plot.bar(ax=ax, rot=0)
ax.set_xlabel('Cantidad de Órdenes', fontsize=12)
ax.set_ylabel('Ventas Totales', fontsize=12)
ax.set_title('Top 5 Representantes de Ventas con menor cantidad de órdenes de venta', fontsize=14)
plt.show()

# %% [markdown]
# `Se nota claramente quien fue el que tuvo la menor cantidad de ventas con respecto a los demás`

# %%
df2=pd.DataFrame()

# %%
df2=datos.copy()

# %%
df2['Invoice Date']=df2['Invoice Date'].dt.year

# %%
df2['Invoice Date'].value_counts()
# Out:
# Invoice Date
# 2017    30573
# 2019    28021
# 2018     6686
# Name: count, dtype: int64

# %%
df2.groupby('Invoice Date')['Sales Amount'].sum()
# Out:
# Invoice Date
# 2017    87462234.49
# 2018    20817471.00
# 2019    77906591.65
# Name: Sales Amount, dtype: float64

# %%
# Gráfico de líneas para ventas por fecha:
datos.groupby('Invoice Date')['Sales Amount'].sum().plot()
# Out:
# <Axes: xlabel='Invoice Date'>

# %%
# Gráfico de líneas para ventas por fecha (TOP 5)

# Agrupar por 'Invoice Date' y sumar las 'Sales Amount'
ventas_por_fecha = datos.groupby('Invoice Date')['Sales Amount'].sum()

# Ordenar de manera descendente las ventas por fecha
ventas_por_fecha = ventas_por_fecha.sort_values(ascending=False)

# Obtener las top 5 fechas con mayores ventas
top_5_fechas = ventas_por_fecha.head(5)

# Crear el gráfico de líneas
fig, ax = plt.subplots(figsize=(12, 6))
top_5_fechas.plot(ax=ax, marker='o', linestyle='-')
ax.set_xlabel('Fecha de Factura', fontsize=12)
ax.set_ylabel('Ventas Totales', fontsize=12)
ax.set_title('Top 5 Fechas con Mayores Ventas Totales', fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# `Se observa cual fue el día en el que las ventas estuvieron en su mayor auge.`

# %% [markdown]
# ## **Verificación de la calidad de los datos**

# %%
print("\nCantidad de valores únicos en cada columna:")
datos.nunique()
# Out:
# Cantidad de valores únicos en cada columna:
# Custkey                               615
# DateKey                               559
# Discount Amount                     17818
# Invoice Date                          559
# Invoice Number                      24679
# Item Class                             16
# Item Number                           983
# Item                                  657
# Line Number                           397
# List Price                           1062
# Order Number                        17796
# Promised Delivery Date                592
# Sales Amount                        17895
# Sales Amount Based on List Price     4060
# Sales Cost Amount                    5513
# Sales Margin Amount                 21295
# Sales Price                         14788
# Sales Quantity                        281
# Sales Rep                              64
# U/M                                     4
# dtype: int64

# %%
print("Los valores nulos de cada columna son: \n")
datos.isnull().sum()
# Out:
# Los valores nulos de cada columna son:
# Custkey                                0
# DateKey                                0
# Discount Amount                        2
# Invoice Date                           0
# Invoice Number                         0
# Item Class                          8285
# Item Number                           40
# Item                                   0
# Line Number                            0
# List Price                             0
# Order Number                           0
# Promised Delivery Date                 0
# Sales Amount                           0
# Sales Amount Based on List Price       0
# Sales Cost Amount                      0
# Sales Margin Amount                    0
# Sales Price                            1
# Sales Quantity                         0
# Sales Rep                              0
# U/M                                    0
# dtype: int64

# %% [markdown]
# Se puede observar que en este conjunto de datos con más de 50,000 filas de datos a algunas columnas les valtan valores, como son las de Discount Amount, Item Class, Item Number y Sales Price.

# %%
print("Los valores duplicados de cada columna son:")
datos.duplicated().sum()
# Out:
# Los valores duplicados de cada columna son:
# 0

# %% [markdown]
# # Preparación de datos

# %% [markdown]
# ## **Selección de datos**

# %%
import numpy as np

# %%
# Mostrar las primeras filas de datos
print("Datos originales:")
datos.head()
# Out:
# Datos originales:
#     Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31           398.73   2019-12-31          329568
# 1  10016609 2019-12-31           268.67   2019-12-31          329569
# 2  10016609 2019-12-31           398.73   2019-12-31          329569
# 3  10016609 2019-12-31           466.45   2019-12-31          329569
# 4  10016609 2019-12-31           515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number  List Price  \
# 0        P01       15640         Super Vegetable Oil         1000      163.47
# 1        P01       31681  Golden Fajita French Fries         7000      275.37
# 2        P01       15640         Super Vegetable Oil         4000      163.47
# 3        P01       13447            High Top Oranges         3000      119.52
# 4        P01       36942       Tell Tale New Potatos         9000      264.18
#
#    Order Number Promised Delivery Date  Sales Amount  \
# 0        122380             2019-12-31        418.62
# 1        123966             2019-12-31        282.07
# 2        123966             2019-12-31        418.62
# 3        123966             2019-12-31        489.71
# 4        123966             2019-12-31        541.21
#
#    Sales Amount Based on List Price  Sales Cost Amount  Sales Margin Amount  \
# 0                            817.35             102.99               315.63
# 1                            550.74             117.45               164.62
# 2                            817.35             102.99               315.63
# 3                            956.16             213.29               276.42
# 4                           1056.72             290.56               250.65
#
#    Sales Price  Sales Quantity  Sales Rep U/M
# 0     83.72400               5        176  EA
# 1    141.03500               2        176  EA
# 2     83.72400               5        176  EA
# 3     61.21375               8        176  EA
# 4    135.30250               4        176  EA

# %%
# ------------------------------------------------------------
# Selección de una muestra o subconjunto
# ------------------------------------------------------------
# Queremos una muestra del 20% de los datos
muestra = datos.sample(frac=0.2, random_state=42)

print("\nMuestra del 20% de los datos:")
muestra
# Out:
# Muestra del 20% de los datos:
#         Custkey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 6752   10023793 2019-10-13         224.6600   2019-10-13          314600
# 43892  10027370 2017-09-19        1471.9000   2017-09-19          113466
# 59143  10012715 2017-03-18        8266.2100   2017-03-18          125396
# 31420  10019066 2018-02-14         459.3400   2018-02-14          223464
# 39975  10023538 2017-11-04         393.4000   2017-11-04          117572
# ...         ...        ...              ...          ...             ...
# 48227  10012715 2017-07-31         958.7402   2017-07-31          109038
# 37225  10006037 2017-12-01         347.0100   2017-12-01          127860
# 7667   10023793 2019-10-05         189.3200   2019-10-05          313743
# 8578   10023757 2019-09-27         332.1000   2019-09-27          313015
# 30968  10007564 2018-02-19        1078.0000   2018-02-19          223820
#
#       Item Class Item Number                         Item  Line Number  \
# 6752         P01       29062    Nationeel Low Fat Popcorn         2000
# 43892        P01       34581            Super White Sugar        34000
# 59143        P01       48500  Red Spade Low Fat Cole Slaw       192000
# 31420        P01       39680    Even Better String Cheese        35000
# 39975        NaN       64851  Footnote Seasoned Hamburger        23000
# ...          ...         ...                          ...          ...
# 48227        P01       28500                 Ebony Squash         7000
# 37225        P01       39030      Nationeel Fudge Cookies         1000
# 7667         P01       25300            Fast Dried Apples         6000
# 8578         NaN       63253            Token Apple Drink         8000
# 30968        P01       25300            Fast Dried Apples         6000
#
#        List Price  Order Number Promised Delivery Date  Sales Amount  \
# 6752     157.7600        111216             2019-10-13        248.62
# 43892    157.7600        209737             2017-09-12       1683.30
# 59143   1134.7700        220895             2017-03-17       8755.34
# 31420    263.1500        319020             2018-02-14        593.26
# 39975     37.2000        211908             2017-11-04        350.60
# ...           ...           ...                    ...           ...
# 48227   1058.6801        207468             2017-07-30       1158.62
# 37225    148.7700        222026             2017-12-01        396.84
# 7667     199.4100        111219             2019-10-05        209.50
# 8578     349.8100        110060             2019-09-27        367.52
# 30968    199.4100        319717             2018-02-19       1314.92
#
#        Sales Amount Based on List Price  Sales Cost Amount  \
# 6752                           473.2800             136.19
# 43892                         3155.2000             958.23
# 59143                        17021.5500            4903.07
# 31420                         1052.6000             406.10
# 39975                          744.0000             154.82
# ...                                 ...                ...
# 48227                         2117.3602             619.29
# 37225                          743.8500             226.36
# 7667                           398.8200             111.87
# 8578                           699.6200             183.42
# 30968                         2392.9200             671.24
#
#        Sales Margin Amount  Sales Price  Sales Quantity  Sales Rep U/M
# 6752                112.43    82.873333               3        115  EA
# 43892               725.07    84.165000              20        107  SE
# 59143              3852.27   583.689333              15        180  EA
# 31420               187.16   148.315000               4        108  EA
# 39975               195.78    17.530000              20        143  EA
# ...                    ...          ...             ...        ...  ..
# 48227               539.33   579.310000               2        180  EA
# 37225               170.48    79.368000               5        134  PR
# 7667                 97.63   104.750000               2        115  EA
# 8578                184.10   183.760000               2        120  EA
# 30968               643.68   109.576667              12        161  EA
#
# [13056 rows x 20 columns]

# %%
# ------------------------------------------------------------
# Agregación de registros
# ------------------------------------------------------------
# Queremos obtener las ventas totales por ItemNumber
ventas_por_item = datos.groupby('Item Number')['Sales Amount'].sum().reset_index()

print("\nVentas totales por ItemNumber:")
print(ventas_por_item)
# Out:
# Ventas totales por ItemNumber:
#             Item Number  Sales Amount
# 0                     0       3383.00
# 1                  2040      23553.61
# 2                  5320        995.03
# 3                  5742     299872.50
# 4                  6341       1854.77
# ..                  ...           ...
# 978  SUPER WINCH T-1500      24820.00
# 979                 TLR       3003.41
# 980         TLR - OCEAN       6416.16
# 981             TLR/BTS       2590.70
# 982             TLR/SEA       3746.47
#
# [983 rows x 2 columns]

# %%
# ------------------------------------------------------------
# Derivación de nuevos atributos
# ------------------------------------------------------------
# Crear un nuevo atributo 'Margen_Porcentaje' calculado a partir de otros campos
datos['Margen_Porcentaje'] = (datos['Sales Margin Amount'] / datos['Sales Amount']) * 100

print("\nDatos con nuevo atributo 'Margen_Porcentaje':")
print(datos[['Item Number', 'Sales Amount', 'Sales Margin Amount', 'Margen_Porcentaje']].head())
# Out:
# Datos con nuevo atributo 'Margen_Porcentaje':
#   Item Number  Sales Amount  Sales Margin Amount  Margen_Porcentaje
# 0       15640        418.62               315.63          75.397735
# 1       31681        282.07               164.62          58.361400
# 2       15640        418.62               315.63          75.397735
# 3       13447        489.71               276.42          56.445652
# 4       36942        541.21               250.65          46.312891

# %%
# ------------------------------------------------------------
# Clasificación de datos para modelado
# ------------------------------------------------------------
# Este paso puede variar según los requisitos del modelo
# Por ahora, nos enfocaremos en convertir tipos de datos numéricos

# Convertir tipos de datos numéricos
columnas_numericas = ['Discount Amount', 'List Price', 'Sales Amount',
                     'Sales Amount Based on List Price', 'Sales Cost Amount',
                     'Sales Margin Amount', 'Sales Price', 'Sales Quantity']

for col in columnas_numericas:
  datos[col] = datos[col].astype('float')

print("\nTipos de datos numéricos convertidos:")
print(datos[columnas_numericas].dtypes)
# Out:
# Tipos de datos numéricos convertidos:
# Discount Amount                     float64
# List Price                          float64
# Sales Amount                        float64
# Sales Amount Based on List Price    float64
# Sales Cost Amount                   float64
# Sales Margin Amount                 float64
# Sales Price                         float64
# Sales Quantity                      float64
# dtype: object

# %% [markdown]
# ## **Limpieza de datos**

# %%
# Imprimir estadísticas descriptivas básicas
print("Estadísticas descriptivas:")
print(datos.describe())
# Out:
# Estadísticas descriptivas:
#             Custkey                        DateKey  Discount Amount  \
# count  6.528000e+04                          65280     65278.000000
# mean   1.001770e+07  2018-06-11 13:06:54.264706048      1855.628805
# min    1.000045e+07            2017-01-01 00:00:00   -255820.800000
# 25%    1.001272e+07            2017-07-24 00:00:00       246.067500
# 50%    1.001966e+07            2018-01-29 00:00:00       441.760000
# 75%    1.002351e+07            2019-06-17 00:00:00       999.760000
# max    1.002758e+07            2019-12-31 00:00:00    343532.660000
# std    7.175933e+03                            NaN      9037.273883
#
#                         Invoice Date  Invoice Number    Line Number  \
# count                          65280    65280.000000   65280.000000
# mean   2018-06-11 13:06:54.264706048   216227.222089   23714.515043
# min              2017-01-01 00:00:00   100080.000000    1000.000000
# 25%              2017-07-24 00:00:00   117931.000000    3000.000000
# 50%              2018-01-29 00:00:00   222870.500000   12000.000000
# 75%              2019-06-17 00:00:00   314319.250000   32000.000000
# max              2019-12-31 00:00:00   332842.000000  344000.000000
# std                              NaN    94991.559484   32664.303299
#
#          List Price   Order Number         Promised Delivery Date  \
# count  65280.000000   65280.000000                          65280
# mean     514.705779  180582.468673  2018-06-08 20:55:22.058823424
# min        0.000000  100838.000000            2008-12-15 00:00:00
# 25%      181.560000  115319.750000            2017-07-23 00:00:00
# 50%      325.190000  203702.000000            2018-01-29 00:00:00
# 75%      803.860000  218576.000000            2019-06-17 00:00:00
# max     2760.700000  321532.000000            2019-12-31 00:00:00
# std      449.190065   67594.820895                            NaN
#
#         Sales Amount  Sales Amount Based on List Price  Sales Cost Amount  \
# count   65280.000000                      65280.000000       65280.000000
# mean     2852.118522                       4707.607727        1661.030116
# min       200.010000                          0.000000           0.000000
# 25%       308.410000                        561.040000         167.790000
# 50%       553.970000                        998.160000         304.530000
# 75%      1280.070000                       2316.630000         687.400000
# max    555376.000000                     632610.160000      366576.000000
# std     15164.567492                      20696.746564        9556.627220
#
#        Sales Margin Amount   Sales Price  Sales Quantity     Sales Rep  \
# count         65280.000000  65279.000000    65280.000000  65280.000000
# mean           1191.088407    283.619763       45.085631    137.421998
# min           -3932.930000  -5000.000000       -1.000000    103.000000
# 25%             129.947500    100.070000        2.000000    113.000000
# 50%             246.490000    183.757500        3.000000    134.000000
# 75%             579.600000    448.220000        8.000000    160.000000
# max          188800.000000   6035.000000    16000.000000    185.000000
# std            5860.874897    252.879249      429.668309     26.643601
#
#        Margen_Porcentaje
# count       65280.000000
# mean           44.180348
# min          -409.868336
# 25%            34.253416
# 50%            45.205349
# 75%            53.294923
# max           100.000000
# std            17.834609

# %%
print(datos.columns)
# Out:
# Index(['Custkey', 'DateKey', 'Discount Amount', 'Invoice Date',
#        'Invoice Number', 'Item Class', 'Item Number', 'Item', 'Line Number',
#        'List Price', 'Order Number', 'Promised Delivery Date', 'Sales Amount',
#        'Sales Amount Based on List Price', 'Sales Cost Amount',
#        'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Rep',
#        'U/M', 'Margen_Porcentaje'],
#       dtype='object')

# %%
# Identificar columnas numéricas
cols_numericas = ['Discount Amount', 'List Price', 'Sales Amount', 'Sales Amount Based on List Price',
                  'Sales Cost Amount', 'Sales Margin Amount', 'Sales Price', 'Sales Quantity']

# Convert columns to string type
datos[cols_numericas] = datos[cols_numericas].astype(str)

# Eliminar filas con valores no numéricos en columnas numéricas
datos = datos[~datos[cols_numericas].apply(lambda x: x.str.contains('[^0-9\.-]', na=False, regex=True)).any(axis=1)]

# %%
# ------------------------------------------------------------
# Manejo de datos faltantes
# ------------------------------------------------------------
# Identificar columnas con datos faltantes
missing = datos.isnull().sum()
print("\nColumnas con datos faltantes:")
print(missing[missing > 0])

# Opción 1: Eliminar filas con datos faltantes
datos_sin_nulos = datos.dropna()
print(f"\nDatos sin filas con nulos (quedan {len(datos_sin_nulos)} filas):")
print(datos_sin_nulos.head())

# Opción 2: Imputar valores faltantes con la mediana

try:
  print(len())
  datos_imputada = datos.fillna(datos.median())
  print(f"\nDatos con valores faltantes imputados con la mediana:")
  print(datos_imputada.head())
except Exception as e:
  print(e)
# Out:
# Columnas con datos faltantes:
# Item Class     8125
# Item Number      38
# dtype: int64
#
# Datos sin filas con nulos (quedan 56814 filas):
#     Custkey    DateKey Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31          398.73   2019-12-31          329568
# 1  10016609 2019-12-31          268.67   2019-12-31          329569
# 2  10016609 2019-12-31          398.73   2019-12-31          329569
# 3  10016609 2019-12-31          466.45   2019-12-31          329569
# 4  10016609 2019-12-31          515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number List Price  \
# 0        P01       15640         Super Vegetable Oil         1000     163.47
# 1        P01       31681  Golden Fajita French Fries         7000     275.37
# 2        P01       15640         Super Vegetable Oil         4000     163.47
# 3        P01       13447            High Top Oranges         3000     119.52
# 4        P01       36942       Tell Tale New Potatos         9000     264.18
#
#    ...  Promised Delivery Date Sales Amount Sales Amount Based on List Price  \
# 0  ...              2019-12-31       418.62                           817.35
# 1  ...              2019-12-31       282.07                           550.74
# 2  ...              2019-12-31       418.62                           817.35
# 3  ...              2019-12-31       489.71                           956.16
# 4  ...              2019-12-31       541.21                          1056.72
#
#   Sales Cost Amount Sales Margin Amount Sales Price Sales Quantity Sales Rep  \
# 0            102.99              315.63      83.724            5.0       176
# 1            117.45              164.62     141.035            2.0       176
# 2            102.99              315.63      83.724            5.0       176
# 3            213.29              276.42    61.21375            8.0       176
# 4            290.56              250.65    135.3025            4.0       176
#
#    U/M Margen_Porcentaje
# 0   EA         75.397735
# 1   EA         58.361400
# 2   EA         75.397735
# 3   EA         56.445652
# 4   EA         46.312891
#
# [5 rows x 21 columns]
# len() takes exactly one argument (0 given)

# %%
# ------------------------------------------------------------
# Manejo de valores atípicos
# ------------------------------------------------------------

# Reemplazar valores no numéricos por NaN en la columna 'Sales Amount'
datos['Sales Amount'] = pd.to_numeric(datos['Sales Amount'], errors='coerce')

# Identificar valores atípicos en la columna 'Sales Amount'
q1 = datos['Sales Amount'].quantile(0.25)
q3 = datos['Sales Amount'].quantile(0.75)
rango = q3 - q1
limites = [q1 - 1.5 * rango, q3 + 1.5 * rango]
outliers = datos[(datos['Sales Amount'] < limites[0]) | (datos['Sales Amount'] > limites[1])]

print(f"\nValores atípicos en 'Sales Amount' ({len(outliers)} filas):")
print(outliers)

# Opción 1: Eliminar valores atípicos
datos_sin_outliers = datos[(datos['Sales Amount'] >= limites[0]) & (datos['Sales Amount'] <= limites[1])]
print(f"\nDatos sin valores atípicos en 'Sales Amount' (quedan {len(datos_sin_outliers)} filas):")
print(datos_sin_outliers.head())

# Opción 2: Reemplazar valores atípicos con límites
datos['Sales Amount'] = np.clip(datos['Sales Amount'], limites[0], limites[1])
print(f"\nDatos con valores atípicos en 'Sales Amount' reemplazados por límites:")
print(datos.head())
# Out:
# Valores atípicos en 'Sales Amount' (8560 filas):
#         Custkey    DateKey Discount Amount Invoice Date  Invoice Number  \
# 7      10026081 2019-12-31         272.523   2019-12-31          329571
# 8      10026081 2019-12-31        397.8448   2019-12-31          329572
# 9      10026081 2019-12-31         548.252   2019-12-31          329573
# 10     10026081 2019-12-31          447.64   2019-12-31          329574
# 133    10019194 2019-12-31          2817.7   2019-12-31          329620
# ...         ...        ...             ...          ...             ...
# 65215  10021485 2017-01-01        100743.4   2017-01-01          119092
# 65216  10021485 2017-01-01      13194.1017   2017-01-01          119093
# 65220  10020962 2017-01-01          4984.0   2017-01-01          119096
# 65265  10019942 2017-01-01          2833.4   2017-01-01          119167
# 65267  10015824 2017-01-01          7037.6   2017-01-01          119173
#
#       Item Class Item Number                          Item  Line Number  \
# 7            NaN       35009  Better Fancy Canned Sardines         1000
# 8            NaN       35010              Better Rice Soup         1000
# 9            NaN       29277             Monarch Spaghetti         1000
# 10           NaN       35012          Swell Canned Peaches         1000
# 133          P01       29260               Monarch Ravioli       105001
# ...          ...         ...                           ...          ...
# 65215        NaN       35197          Moms Turkey Hot Dogs        12000
# 65216        P01       62055          Big Time Frozen Peas         3001
# 65220        NaN       61619            Better Noodle Soup         1000
# 65265        P01       11690      High Top Dried Mushrooms         3000
# 65267        NaN       39906           Jeffers Wheat Puffs         1000
#
#       List Price  ...  Promised Delivery Date Sales Amount  \
# 7        39.1545  ...              2019-12-31      6540.36
# 8        38.5506  ...              2019-12-31      9548.21
# 9        40.3128  ...              2019-12-31     13158.10
# 10        14.256  ...              2019-12-31     10743.32
# 133       556.63  ...              2019-12-31      2748.60
# ...          ...  ...                     ...          ...
# 65215   384.5168  ...              2017-01-02     91515.00
# 65216   645.6303  ...              2017-01-02     11985.48
# 65220     1246.0  ...              2017-01-01      4984.00
# 65265     192.34  ...              2017-01-01      3129.14
# 65267     1759.4  ...              2017-01-01      7037.60
#
#        Sales Amount Based on List Price Sales Cost Amount Sales Margin Amount  \
# 7                              6812.883           2969.78             3570.58
# 8                             9946.0548           4826.77             4721.44
# 9                             13706.352           6424.27             6733.83
# 10                             11190.96           6258.02              4485.3
# 133                              5566.3           1662.97             1085.63
# ...                                 ...               ...                 ...
# 65215                          192258.4          48692.25            42822.75
# 65216                        25179.5817           7291.92             4693.56
# 65220                            9968.0           3912.85             1071.15
# 65265                           5962.54           1035.02             2094.12
# 65267                           14075.2           4382.29             2655.31
#
#            Sales Price Sales Quantity Sales Rep  U/M Margen_Porcentaje
# 7      37.588275862069          174.0       154   EA         54.593019
# 8      37.008565891473          258.0       154   EA         49.448431
# 9      38.700294117647          340.0       154   EA         51.176310
# 10     13.685757961783          785.0       154   EA         41.749664
# 133             274.86           10.0       108   EA         39.497562
# ...                ...            ...       ...  ...               ...
# 65215           183.03          500.0       141   EA         46.793149
# 65216           307.32           39.0       141   EA         39.160384
# 65220            623.0            8.0       172   EA         21.491774
# 65265           100.94           31.0       109   SE         66.923180
# 65267            879.7            8.0       103   EA         37.730334
#
# [8560 rows x 21 columns]
#
# Datos sin valores atípicos en 'Sales Amount' (quedan 56381 filas):
#     Custkey    DateKey Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31          398.73   2019-12-31          329568
# 1  10016609 2019-12-31          268.67   2019-12-31          329569
# 2  10016609 2019-12-31          398.73   2019-12-31          329569
# 3  10016609 2019-12-31          466.45   2019-12-31          329569
# 4  10016609 2019-12-31          515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number List Price  \
# 0        P01       15640         Super Vegetable Oil         1000     163.47
# 1        P01       31681  Golden Fajita French Fries         7000     275.37
# 2        P01       15640         Super Vegetable Oil         4000     163.47
# 3        P01       13447            High Top Oranges         3000     119.52
# 4        P01       36942       Tell Tale New Potatos         9000     264.18
#
#    ...  Promised Delivery Date Sales Amount  Sales Amount Based on List Price  \
# 0  ...              2019-12-31       418.62                            817.35
# 1  ...              2019-12-31       282.07                            550.74
# 2  ...              2019-12-31       418.62                            817.35
# 3  ...              2019-12-31       489.71                            956.16
# 4  ...              2019-12-31       541.21                           1056.72
#
#   Sales Cost Amount Sales Margin Amount Sales Price Sales Quantity Sales Rep  \
# 0            102.99              315.63      83.724            5.0       176
# 1            117.45              164.62     141.035            2.0       176
# 2            102.99              315.63      83.724            5.0       176
# 3            213.29              276.42    61.21375            8.0       176
# 4            290.56              250.65    135.3025            4.0       176
#
#    U/M Margen_Porcentaje
# 0   EA         75.397735
# 1   EA         58.361400
# 2   EA         75.397735
# 3   EA         56.445652
# 4   EA         46.312891
#
# [5 rows x 21 columns]
#
# Datos con valores atípicos en 'Sales Amount' reemplazados por límites:
#     Custkey    DateKey Discount Amount Invoice Date  Invoice Number  \
# 0  10016609 2019-12-31          398.73   2019-12-31          329568
# 1  10016609 2019-12-31          268.67   2019-12-31          329569
# 2  10016609 2019-12-31          398.73   2019-12-31          329569
# 3  10016609 2019-12-31          466.45   2019-12-31          329569
# 4  10016609 2019-12-31          515.51   2019-12-31          329569
#
#   Item Class Item Number                        Item  Line Number List Price  \
# 0        P01       15640         Super Vegetable Oil         1000     163.47
# 1        P01       31681  Golden Fajita French Fries         7000     275.37
# 2        P01       15640         Super Vegetable Oil         4000     163.47
# 3        P01       13447            High Top Oranges         3000     119.52
# 4        P01       36942       Tell Tale New Potatos         9000     264.18
#
#    ...  Promised Delivery Date Sales Amount  Sales Amount Based on List Price  \
# 0  ...              2019-12-31       418.62                            817.35
# 1  ...              2019-12-31       282.07                            550.74
# 2  ...              2019-12-31       418.62                            817.35
# 3  ...              2019-12-31       489.71                            956.16
# 4  ...              2019-12-31       541.21                           1056.72
#
#   Sales Cost Amount Sales Margin Amount Sales Price Sales Quantity Sales Rep  \
# 0            102.99              315.63      83.724            5.0       176
# 1            117.45              164.62     141.035            2.0       176
# 2            102.99              315.63      83.724            5.0       176
# 3            213.29              276.42    61.21375            8.0       176
# 4            290.56              250.65    135.3025            4.0       176
#
#    U/M Margen_Porcentaje
# 0   EA         75.397735
# 1   EA         58.361400
# 2   EA         75.397735
# 3   EA         56.445652
# 4   EA         46.312891
#
# [5 rows x 21 columns]
# C:\Users\USER\AppData\Local\Temp\ipykernel_13184\3380075764.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Sales Amount'] = pd.to_numeric(datos['Sales Amount'], errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_13184\3380075764.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Sales Amount'] = np.clip(datos['Sales Amount'], limites[0], limites[1])

# %% [markdown]
# ## **Construcción de nuevos datos**

# %%
import pandas as pd
# Derivación de atributos (columnas o características)
datos['Discount Amount'] = pd.to_numeric(datos['Discount Amount'], errors='coerce')

# Crear un nuevo atributo 'Tiempo_Entrega' calculado a partir de otros campos
datos['Tiempo_Entrega'] = (datos['Promised Delivery Date'] - datos['Invoice Date']).dt.days

# Generación de registros (filas)
# Supongamos que queremos crear nuevos registros con el descuento promedio por año
descuentos_por_anio = datos.groupby(datos['Invoice Date'].dt.year)['Discount Amount'].mean().reset_index()
descuentos_por_anio.columns = ['Anio', 'Descuento_Promedio']

print("Nuevos registros con descuento promedio por año:")
print(descuentos_por_anio)

# Dividir los datos en datos_clientes y datos_productos
datos_clientes = datos.iloc[:2]  # Supongamos que los datos de clientes están en las primeras dos filas
datos_productos = datos.iloc[2:]  # El resto de los datos son datos de productos
# Out:
# Nuevos registros con descuento promedio por año:
#    Anio  Descuento_Promedio
# 0  2017         1822.886693
# 1  2018         1837.646584
# 2  2019         1917.564535
# C:\Users\USER\AppData\Local\Temp\ipykernel_13184\2185187467.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Discount Amount'] = pd.to_numeric(datos['Discount Amount'], errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_13184\2185187467.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Tiempo_Entrega'] = (datos['Promised Delivery Date'] - datos['Invoice Date']).dt.days

# %% [markdown]
# ## **Integración de datos**

# %%
# Fusión de datos (unir dos conjuntos de datos con registros similares, pero con atributos diferentes)
datos_clientes = datos[['Custkey', 'Margen_Porcentaje']]  # Supongamos que 'Margen_Porcentaje' está en los datos de clientes
datos_productos = datos[['Item Number', 'Item Class']]  # Supongamos que 'Item Class' está en los datos de productos

datos_integrados = pd.merge(datos, datos_clientes, on='Custkey', how='left')
datos_integrados = pd.merge(datos_integrados, datos_productos, on='Item Number', how='left')

print("Datos integrados después de la fusión:")
print(datos_integrados.head())

# Adición de datos (integrar dos o más conjuntos de datos con atributos similares, pero con registros diferentes)
datos_agregados = datos.groupby(['Item Number', 'Item Class']).agg({'Sales Amount': 'sum',
                                                                    'Sales Quantity': 'sum'}).reset_index()
datos_agregados = pd.merge(datos_agregados, datos_productos, on='Item Number', how='left')

print("\nDatos agregados después de la adición:")
print(datos_agregados.head())

# %% [markdown]
# ## **Formato de datos**

# %%
import pandas as pd
# Convertir las fechas a objetos de fecha y hora
datos['Invoice Date'] = pd.to_datetime(datos['Invoice Date'], errors='coerce')

# Eliminar filas con fechas inválidas (NaN)
datos = datos.dropna(subset=['Invoice Date'])

# Ordenar los datos por fecha e número de factura
datos_ordenados = datos.sort_values(by=['Invoice Date', 'Invoice Number'])

print("Datos ordenados por fecha y número de factura:")
print(datos_ordenados.head())

# %%
print(datos.columns)

# %% [markdown]
# # Canasta v1

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Agrupar los datos por 'Invoice Number' y 'Item' para obtener una lista de productos por factura
basket = datos.groupby(['Invoice Number', 'Item'])['Sales Quantity'].sum().unstack().reset_index().fillna(0).set_index('Invoice Number')

# Convertir todos los valores a numéricos, reemplazando los errores con 0
basket = basket.apply(pd.to_numeric, errors='coerce').fillna(0)

# Convertir las cantidades en valores binarios (0 o 1)
basket = basket.applymap(lambda x: 1 if x > 0 else 0)

# Aplicar el algoritmo Apriori
frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)

# Generar las reglas de asociación
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Mostrar las reglas
print(rules.head())

# Visualización de los resultados
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
plt.title('Soporte vs Confianza')
plt.xlabel('Soporte')
plt.ylabel('Confianza')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13184\279537281.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket = basket.applymap(lambda x: 1 if x > 0 else 0)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                           antecedents                         consequents  \
# 0      (Better Fancy Canned Sardines)  (Big Time Home Style French Fries)
# 1  (Big Time Home Style French Fries)      (Better Fancy Canned Sardines)
# 2      (Better Fancy Canned Sardines)         (Bravo Large Canned Shrimp)
# 3         (Bravo Large Canned Shrimp)      (Better Fancy Canned Sardines)
# 4      (Better Fancy Canned Sardines)              (Ebony Prepared Salad)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.066060            0.017801  0.010166    0.153894  8.645225
# 1            0.017801            0.066060  0.010166    0.571101  8.645225
# 2            0.066060            0.038256  0.012453    0.188504  4.927467
# 3            0.038256            0.066060  0.012453    0.325507  4.927467
# 4            0.066060            0.058221  0.018577    0.281211  4.830091
#
#    leverage  conviction  zhangs_metric
# 0  0.008990    1.160846       0.946880
# 1  0.008990    2.177529       0.900356
# 2  0.009925    1.185150       0.853434
# 3  0.009925    1.384655       0.828761
# 4  0.014731    1.310231       0.849053

# %%
import matplotlib.pyplot as plt
# Visualización de los resultados
plt.figure(figsize=(10, 6))
plt.scatter(rules['support'], rules['confidence'], alpha=0.5, c=rules['lift'], cmap='viridis')
plt.colorbar(label='Lift')
plt.title('Soporte vs Confianza')
plt.xlabel('Soporte')
plt.ylabel('Confianza')
plt.show()

# %% [markdown]
# # Canasta V2

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Preprocesar los datos: Agrupar los productos por el número de factura
grouped_data = datos.groupby('Invoice Number')['Item'].apply(list)

# Crear la matriz de transacciones
te = TransactionEncoder()
te_ary = te.fit(grouped_data).transform(grouped_data)
df_transactions = pd.DataFrame(te_ary, columns=te.columns_)

# Aplicar el algoritmo de Apriori
frequent_itemsets = apriori(df_transactions, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# Mostrar los resultados
print("Conjuntos de elementos frecuentes")
print(frequent_itemsets.head())

print("\nReglas de asociación")
print(rules.head())
# Out:
# Conjuntos de elementos frecuentes
#     support                         itemsets
# 0  0.034173      (Atomic Mint Chocolate Bar)
# 1  0.011064          (BBB Best Apple Butter)
# 2  0.015760  (BBB Best Chunky Peanut Butter)
# 3  0.010166                (BBB Best Pepper)
# 4  0.014657      (Best Choice Sugar Cookies)
#
# Reglas de asociación
#                           antecedents                         consequents  \
# 0         (Atomic Mint Chocolate Bar)              (Ebony Prepared Salad)
# 1              (Ebony Prepared Salad)         (Atomic Mint Chocolate Bar)
# 2      (Better Fancy Canned Sardines)  (Big Time Home Style French Fries)
# 3  (Big Time Home Style French Fries)      (Better Fancy Canned Sardines)
# 4      (Better Fancy Canned Sardines)         (Bravo Large Canned Shrimp)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.034173            0.059078  0.010207    0.298686  5.055778
# 1            0.059078            0.034173  0.010207    0.172771  5.055778
# 2            0.066672            0.017801  0.010166    0.152480  8.565814
# 3            0.017801            0.066672  0.010166    0.571101  8.565814
# 4            0.066672            0.038337  0.012453    0.186773  4.871807
#
#    leverage  conviction  zhangs_metric
# 0  0.008188    1.341655       0.830590
# 1  0.008188    1.167545       0.852575
# 2  0.008979    1.158910       0.946352
# 3  0.008979    2.176101       0.899265
# 4  0.009896    1.182526       0.851509

# %%
# Aplicar el algoritmo de Apriori con un soporte mínimo del 2%
frequent_itemsets = apriori(df_transactions, min_support=0.01, use_colnames=True)

# Generar reglas de asociación con una confianza mínima del 30%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Mostrar los resultados
print("Conjuntos de elementos frecuentes")
print(frequent_itemsets.head())

print("\nReglas de asosiación")
print(rules.head())
# Out:
# Conjuntos de elementos frecuentes
#     support                         itemsets
# 0  0.034173      (Atomic Mint Chocolate Bar)
# 1  0.011064          (BBB Best Apple Butter)
# 2  0.015760  (BBB Best Chunky Peanut Butter)
# 3  0.010166                (BBB Best Pepper)
# 4  0.014657      (Best Choice Sugar Cookies)
#
# Reglas de asosiación
#                                antecedents                     consequents  \
# 0       (Big Time Home Style French Fries)  (Better Fancy Canned Sardines)
# 1                        (Tell Tale Limes)         (Gorilla String Cheese)
# 2                  (Gorilla String Cheese)               (Tell Tale Limes)
# 3              (Nationeel Salted Pretzels)      (High Top Dried Mushrooms)
# 4  (Moms Sliced Turkey, Imagine Popsicles)          (Ebony Prepared Salad)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.017801            0.066672  0.010166    0.571101   8.565814
# 1            0.022170            0.015474  0.011554    0.521179  33.681341
# 2            0.015474            0.022170  0.011554    0.746702  33.681341
# 3            0.029110            0.043441  0.017393    0.597475  13.753728
# 4            0.016209            0.059078  0.010615    0.654912  11.085526
#
#    leverage  conviction  zhangs_metric
# 0  0.008979    2.176101       0.899265
# 1  0.011211    2.056145       0.992309
# 2  0.011211    3.860393       0.985560
# 3  0.016128    2.376399       0.955096
# 4  0.009658    2.726613       0.924782
